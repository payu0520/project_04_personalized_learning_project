# %%
# 📌 Step 1: Data Loading & Exploration
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.cluster import KMeans
import pickle
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("new_student_dataset_25.csv")
df = df.loc[:, ~df.columns.str.contains('^Unnamed')] 
df
# Out:
#    student_id  hours_studied  previous_scores learning_style  \
# 0        S001            3.6             83.2    Kinesthetic
# 1        S002            7.7             51.0       Auditory
# 2        S003            6.1             68.3       Auditory
# 3        S004            5.2             72.6       Auditory
# 4        S005            2.1             42.6       Auditory
# 5        S006            2.1             73.4       Auditory
# 6        S007            1.4             49.4       Auditory
# 7        S008            7.1             43.6    Kinesthetic
# 8        S009            5.2             92.2    Kinesthetic
# 9        S010            6.0             93.1       Auditory
# 10       S011            1.1             84.5    Kinesthetic
# 11       S012            7.8             56.8         Visual
# 12       S013            6.8             45.4       Auditory
# 13       S014            2.5             77.6         Visual
# 14       S015            2.3             64.2         Visual
# 15       S016            2.3             46.7       Auditory
# 16       S017            3.1             67.2    Kinesthetic
# 17       S018            4.7             41.9         Visual
# 18       S019            4.0             90.0       Auditory
# 19       S020            3.0             54.2         Visual
# 20       S021            5.3             76.4         Visual
# 21       S022            2.0             57.1         Visual
# 22       S023            3.0             68.6         Visual
# 23       S024            3.6             70.1    Kinesthetic
# 24       S025            4.2             50.2         Visual
#
#    interest_subjects  assignments_done  test_score
# 0               Math              92.5        76.3
# 1               Math              72.5        72.4
# 2            History              54.8        52.2
# 3               Math              68.5        96.6
# 4            English              83.4        75.9
# 5               Math              83.3        81.7
# 6            English              79.6        92.8
# 7            English              63.7        77.5
# 8            English              78.1        57.7
# 9            History              69.1        46.3
# 10           History              98.6        67.4
# 11           History              92.4        53.1
# 12              Math              86.1        65.0
# 13           English              61.8        93.0
# 14           History              62.8        59.5
# 15           History              52.0        47.3
# 16              Math              85.5        61.4
# 17           History              55.5        94.4
# 18              Math              72.0        56.3
# 19           Science              60.1        78.9
# 20           History              94.8        40.0
# 21           Science              73.8        61.2
# 22              Math              78.2        58.3
# 23           English              84.8        49.9
# 24           History              57.0        72.0

# %%
# 📌 Encode categorical features
le = LabelEncoder()
df['learning_style_encoded'] = le.fit_transform(df['learning_style'])
df['interest_subject_encoded'] = le.fit_transform(df['interest_subjects'])

# %%
df
# Out:
#    student_id  hours_studied  previous_scores learning_style  \
# 0        S001            3.6             83.2    Kinesthetic
# 1        S002            7.7             51.0       Auditory
# 2        S003            6.1             68.3       Auditory
# 3        S004            5.2             72.6       Auditory
# 4        S005            2.1             42.6       Auditory
# 5        S006            2.1             73.4       Auditory
# 6        S007            1.4             49.4       Auditory
# 7        S008            7.1             43.6    Kinesthetic
# 8        S009            5.2             92.2    Kinesthetic
# 9        S010            6.0             93.1       Auditory
# 10       S011            1.1             84.5    Kinesthetic
# 11       S012            7.8             56.8         Visual
# 12       S013            6.8             45.4       Auditory
# 13       S014            2.5             77.6         Visual
# 14       S015            2.3             64.2         Visual
# 15       S016            2.3             46.7       Auditory
# 16       S017            3.1             67.2    Kinesthetic
# 17       S018            4.7             41.9         Visual
# 18       S019            4.0             90.0       Auditory
# 19       S020            3.0             54.2         Visual
# 20       S021            5.3             76.4         Visual
# 21       S022            2.0             57.1         Visual
# 22       S023            3.0             68.6         Visual
# 23       S024            3.6             70.1    Kinesthetic
# 24       S025            4.2             50.2         Visual
#
#    interest_subjects  assignments_done  test_score  learning_style_encoded  \
# 0               Math              92.5        76.3                       1
# 1               Math              72.5        72.4                       0
# 2            History              54.8        52.2                       0
# 3               Math              68.5        96.6                       0
# 4            English              83.4        75.9                       0
# 5               Math              83.3        81.7                       0
# 6            English              79.6        92.8                       0
# 7            English              63.7        77.5                       1
# 8            English              78.1        57.7                       1
# 9            History              69.1        46.3                       0
# 10           History              98.6        67.4                       1
# 11           History              92.4        53.1                       2
# 12              Math              86.1        65.0                       0
# 13           English              61.8        93.0                       2
# 14           History              62.8        59.5                       2
# 15           History              52.0        47.3                       0
# 16              Math              85.5        61.4                       1
# 17           History              55.5        94.4                       2
# 18              Math              72.0        56.3                       0
# 19           Science              60.1        78.9                       2
# 20           History              94.8        40.0                       2
# 21           Science              73.8        61.2                       2
# 22              Math              78.2        58.3                       2
# 23           English              84.8        49.9                       1
# 24           History              57.0        72.0                       2
#
#     interest_subject_encoded
# 0                          2
# 1                          2
# 2                          1
# 3                          2
# 4                          0
# 5                          2
# 6                          0
# 7                          0
# 8                          0
# 9                          1
# 10                         1
# 11                         1
# 12                         2
# 13                         0
# 14                         1
# 15                         1
# 16                         2
# 17                         1
# 18                         2
# 19                         3
# 20                         1
# 21                         3
# 22                         2
# 23                         0
# 24                         1

# %%
# 📌 Features & Target
features = ['hours_studied', 'previous_scores', 'assignments_done', 
            'learning_style_encoded', 'interest_subject_encoded']
X = df[features]
y = df['test_score']

# %%
X
# Out:
#     hours_studied  previous_scores  assignments_done  learning_style_encoded  \
# 0             3.6             83.2              92.5                       1
# 1             7.7             51.0              72.5                       0
# 2             6.1             68.3              54.8                       0
# 3             5.2             72.6              68.5                       0
# 4             2.1             42.6              83.4                       0
# 5             2.1             73.4              83.3                       0
# 6             1.4             49.4              79.6                       0
# 7             7.1             43.6              63.7                       1
# 8             5.2             92.2              78.1                       1
# 9             6.0             93.1              69.1                       0
# 10            1.1             84.5              98.6                       1
# 11            7.8             56.8              92.4                       2
# 12            6.8             45.4              86.1                       0
# 13            2.5             77.6              61.8                       2
# 14            2.3             64.2              62.8                       2
# 15            2.3             46.7              52.0                       0
# 16            3.1             67.2              85.5                       1
# 17            4.7             41.9              55.5                       2
# 18            4.0             90.0              72.0                       0
# 19            3.0             54.2              60.1                       2
# 20            5.3             76.4              94.8                       2
# 21            2.0             57.1              73.8                       2
# 22            3.0             68.6              78.2                       2
# 23            3.6             70.1              84.8                       1
# 24            4.2             50.2              57.0                       2
#
#     interest_subject_encoded
# 0                          2
# 1                          2
# 2                          1
# 3                          2
# 4                          0
# 5                          2
# 6                          0
# 7                          0
# 8                          0
# 9                          1
# 10                         1
# 11                         1
# 12                         2
# 13                         0
# 14                         1
# 15                         1
# 16                         2
# 17                         1
# 18                         2
# 19                         3
# 20                         1
# 21                         3
# 22                         2
# 23                         0
# 24                         1

# %%
#spliting data into independant anmd denpendaent variable
x=df[['hours_studied','previous_scores','assignments_done','learning_style_encoded','interest_subject_encoded']]
y=df[['test_score']]

# %%
print (len(df['hours_studied'].unique()))
print (len(df['previous_scores'].unique()))
print (len(df['assignments_done'].unique()))
# Out:
# 20
# 25
# 25

# %%
#implement oneHotEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
ohe=OneHotEncoder()
ohe.fit(x[["hours_studied","previous_scores","assignments_done"]])
# Out:
# OneHotEncoder()

# %%
ohe.categories_
# Out:
# [array([1.1, 1.4, 2. , 2.1, 2.3, 2.5, 3. , 3.1, 3.6, 4. , 4.2, 4.7, 5.2,
#         5.3, 6. , 6.1, 6.8, 7.1, 7.7, 7.8]),
#  array([41.9, 42.6, 43.6, 45.4, 46.7, 49.4, 50.2, 51. , 54.2, 56.8, 57.1,
#         64.2, 67.2, 68.3, 68.6, 70.1, 72.6, 73.4, 76.4, 77.6, 83.2, 84.5,
#         90. , 92.2, 93.1]),
#  array([52. , 54.8, 55.5, 57. , 60.1, 61.8, 62.8, 63.7, 68.5, 69.1, 72. ,
#         72.5, 73.8, 78.1, 78.2, 79.6, 83.3, 83.4, 84.8, 85.5, 86.1, 92.4,
#         92.5, 94.8, 98.6])]

# %%
# 📌 Train Regression Model
reg_model = LinearRegression()
reg_model.fit(X_scaled, y)
# Out:
# LinearRegression()

# %%
# 📌 Train KMeans Clustering
kmeans_model = KMeans(n_clusters=3, random_state=42)
kmeans_model.fit(X_scaled)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
# 📌 Save the models and scaler
with open("model.pkl", "wb") as f:
    pickle.dump(reg_model, f)

with open("clustering.pkl", "wb") as f:
    pickle.dump(kmeans_model, f)

with open("scaler.pkl", "wb") as f:
    pickle.dump(scaler, f)

print("✅ model.pkl, clustering.pkl, and scaler.pkl files created successfully!")
# Out:
# ✅ model.pkl, clustering.pkl, and scaler.pkl files created successfully!
