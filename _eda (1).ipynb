# %%
# 📌 Step 1: Data Loading & Exploration
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("new_student_dataset_25.csv")

# %%
sns.pairplot(df, hue="learning_style")
plt.suptitle("Pairplot of Student Features", y=1.02)
plt.show()

# %%
sns.boxplot(data=df, x="learning_style", y="test_score")
plt.title("Test Score Distribution by Learning Style")
plt.show()

# %%
#Feature Encoding & Scaling
le = LabelEncoder()
df['learning_style_encoded'] = le.fit_transform(df['learning_style'])
df['interest_subject_encoded'] = le.fit_transform(df['interest_subjects'])

features = ['hours_studied', 'previous_scores', 'assignments_done',
            'learning_style_encoded', 'interest_subject_encoded']
X = df[features]
y = df['test_score']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X
# Out:
#     hours_studied  previous_scores  assignments_done  learning_style_encoded  \
# 0             3.6             83.2              92.5                       1
# 1             7.7             51.0              72.5                       0
# 2             6.1             68.3              54.8                       0
# 3             5.2             72.6              68.5                       0
# 4             2.1             42.6              83.4                       0
# 5             2.1             73.4              83.3                       0
# 6             1.4             49.4              79.6                       0
# 7             7.1             43.6              63.7                       1
# 8             5.2             92.2              78.1                       1
# 9             6.0             93.1              69.1                       0
# 10            1.1             84.5              98.6                       1
# 11            7.8             56.8              92.4                       2
# 12            6.8             45.4              86.1                       0
# 13            2.5             77.6              61.8                       2
# 14            2.3             64.2              62.8                       2
# 15            2.3             46.7              52.0                       0
# 16            3.1             67.2              85.5                       1
# 17            4.7             41.9              55.5                       2
# 18            4.0             90.0              72.0                       0
# 19            3.0             54.2              60.1                       2
# 20            5.3             76.4              94.8                       2
# 21            2.0             57.1              73.8                       2
# 22            3.0             68.6              78.2                       2
# 23            3.6             70.1              84.8                       1
# 24            4.2             50.2              57.0                       2
#
#     interest_subject_encoded
# 0                          2
# 1                          2
# 2                          1
# 3                          2
# 4                          0
# 5                          2
# 6                          0
# 7                          0
# 8                          0
# 9                          1
# 10                         1
# 11                         1
# 12                         2
# 13                         0
# 14                         1
# 15                         1
# 16                         2
# 17                         1
# 18                         2
# 19                         3
# 20                         1
# 21                         3
# 22                         2
# 23                         0
# 24                         1

# %%
y
# Out:
# 0     76.3
# 1     72.4
# 2     52.2
# 3     96.6
# 4     75.9
# 5     81.7
# 6     92.8
# 7     77.5
# 8     57.7
# 9     46.3
# 10    67.4
# 11    53.1
# 12    65.0
# 13    93.0
# 14    59.5
# 15    47.3
# 16    61.4
# 17    94.4
# 18    56.3
# 19    78.9
# 20    40.0
# 21    61.2
# 22    58.3
# 23    49.9
# 24    72.0
# Name: test_score, dtype: float64
